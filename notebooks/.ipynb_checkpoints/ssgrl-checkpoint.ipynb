# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd ../src
# Out:
# /home/theo/MVA/graph_mlc/src

# %%
from util import *
from params import *
from imports import *

from data.dataset import *
from data.transforms import *

from model_zoo.common import *
from model_zoo.ssgrl import *

from training.train import *
from training.freezing import *

# %%
seed_everything(SEED)

# %% [markdown]
# # Datasets

# %%
trainval_dataset = MLCDataset(TRAINVAL_IMGS, 
                              transforms=get_transfos(size=IMG_SIZE),
                              img_path=IMG_PATH,
                              annotation_path=ANNOTATION_PATH
                             )

# %%
test_dataset = MLCDataset(TEST_IMGS, 
                          transforms=get_transfos(test=True, size=IMG_SIZE),
                          img_path=IMG_PATH,
                          annotation_path=ANNOTATION_PATH
                         )

# %% [markdown]
# # Loading GloVe Embeddings

# %%
os.listdir(GLOVE_PATH)
# Out:
# ['glove.6B.300d.txt',
#  'glove.6B.200d.txt',
#  'glove.6B.50d.txt',
#  'glove.6B.100d.txt']

# %%
embeddings_dict = {}
with open(GLOVE_PATH + f"glove.6B.{GLOVE_DIM}d.txt", 'r') as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], "float32")
        embeddings_dict[word] = vector

# %%
embeddings_dict['diningtable'] = embeddings_dict['table']
embeddings_dict['pottedplant'] = embeddings_dict['plant']
embeddings_dict['tvmonitor'] = embeddings_dict['tv']

# %%
class_embeddings = np.zeros((NUM_CLASSES, GLOVE_DIM))

# %%
for c in range(len(CLASSES)):
    try:
        class_embeddings[c, :] = np.array(embeddings_dict[CLASSES[c]])
    except:
        print(f"No embedding found for {c}")

# %%
class_embeddings.shape
# Out:
# (20, 300)

# %% [markdown]
# # Building Coocurence Matrix

# %%
THRESHOLD = 0.1
P = 0.25

# %%
y = trainval_dataset.y.astype(int)

# %%
ocurences = np.repeat(np.sum(y, 0, keepdims=True), NUM_CLASSES, axis=0)
union = (ocurences + ocurences.T) / 2

# %%
coocurence = y.T @ y # / union

# %%
coocurence = (coocurence / y.sum(0)).T

# %%
plot_coocurence(coocurence, CLASSES)

# %%
# coocurence = threshold_and_smooth_matrix(coocurence, t=THRESHOLD, p=P)
# plot_coocurence(coocurence, CLASSES)

# %% [markdown]
# # Model

# %%
def train_ssgrl(backbone, train_dataset, val_dataset, 
                coocurence, class_embeddings,
                test_dataset=None, use_si=True,
                cp=False, model_name='model', threshold=0.5):
    
    seed_everything(SEED)
    
    d = 1024 if backbone == "resnet34" else 4096
    model = SSGRLClassifier(backbone, coocurence, class_embeddings, d1=d, d2=d, 
                            use_si=use_si, time_steps=3, logit_fts=d//2).cuda()

    print('\n- Training with frozen backbone : ')

    freeze(model)
    for layer in ['semantic_decoupling', 'semantic_intraction', 'logits', 'fo']:
        unfreeze_layer(model, layer)

    n_parameters = count_parameters(model)
    print(f'    -> {n_parameters} trainable parameters\n')

    fit(model, train_dataset, val_dataset, epochs=3, batch_size=32, warmup_prop=0, lr=1e-3, min_lr=1e-4,
        verbose=1, verbose_eval=1, cp=False, model_name='model')

    print('\n- Training : ')

    if backbone == 'resnet34':
        unfreeze(model)
    else:
        unfreeze_layer(model, 'layer4')
        
    n_parameters = count_parameters(model)
    print(f'    -> {n_parameters} trainable parameters\n')

    fit(model, train_dataset, val_dataset, epochs=5, batch_size=32, warmup_prop=0, lr=1e-4, min_lr=1e-6,
        verbose=1, verbose_eval=1, cp=cp, model_name=model_name)

    print('\n- Evaluating: \n')

    if cp:
        load_model_weights(model, model_name, verbose=1)
        
    pred_val = predict_voc(model, val_dataset)
    print(f' - Scored {voc12_mAP(pred_val) :.3f} on validation data')
    
    if test_dataset is not None:
        pred_test = predict_voc(model, test_dataset)
        print(f' - Scored {voc12_mAP(pred_test) :.3f} on test data\n')
    
    return model

# %%
backbone = 'resnet34'
# backbone = 'resnet101'
# backbone = 'resnext101'

# %%
backbone = 'resnet34'
model = train_ssgrl(backbone, trainval_dataset, test_dataset, coocurence, class_embeddings, 
                    model_name=backbone, use_si=False)
# Out:
# - Training with frozen backbone :
#     -> 2427925 trainable parameters
#
# Epoch 1/3 	 lr=1.0e-03 	 t=14s 	 loss=0.151 	 mAP=0.818 	 val_loss=0.095
# Epoch 2/3 	 lr=5.5e-04 	 t=14s 	 loss=0.101 	 mAP=0.840 	 val_loss=0.087
# Epoch 3/3 	 lr=1.0e-04 	 t=14s 	 loss=0.090 	 mAP=0.843 	 val_loss=0.081
#
# - Training :
#     -> 23712597 trainable parameters
#
# Epoch 1/5 	 lr=1.0e-04 	 t=21s 	 loss=0.093 	 mAP=0.847 	 val_loss=0.079
# Epoch 2/5 	 lr=8.6e-05 	 t=21s 	 loss=0.067 	 mAP=0.858 	 val_loss=0.078
# Epoch 3/5 	 lr=5.1e-05 	 t=21s 	 loss=0.051 	 mAP=0.861 	 val_loss=0.074
# Epoch 4/5 	 lr=1.5e-05 	 t=21s 	 loss=0.039 	 mAP=0.869 	 val_loss=0.072
# Epoch 5/5 	 lr=1.0e-06 	 t=21s 	 loss=0.035 	 mAP=0.868 	 val_loss=0.072
#
# - Evaluating:
#
#  - Scored 0.868 on validation data

# %%
backbone = 'resnet34'
model = train_ssgrl(backbone, trainval_dataset, test_dataset, coocurence, class_embeddings, 
                    model_name=backbone, use_si=True)
# Out:
# - Training with frozen backbone :
#     -> 2952213 trainable parameters
#
# Epoch 1/3 	 lr=1.0e-03 	 t=15s 	 loss=0.151 	 mAP=0.824 	 val_loss=0.091
# Epoch 2/3 	 lr=5.5e-04 	 t=15s 	 loss=0.099 	 mAP=0.841 	 val_loss=0.085
# Epoch 3/3 	 lr=1.0e-04 	 t=15s 	 loss=0.089 	 mAP=0.844 	 val_loss=0.081
#
# - Training :
#     -> 26596181 trainable parameters
#
# Epoch 1/5 	 lr=1.0e-04 	 t=22s 	 loss=0.093 	 mAP=0.851 	 val_loss=0.080
# Epoch 2/5 	 lr=8.6e-05 	 t=22s 	 loss=0.068 	 mAP=0.852 	 val_loss=0.079
# Epoch 3/5 	 lr=5.1e-05 	 t=22s 	 loss=0.052 	 mAP=0.862 	 val_loss=0.075
# Epoch 4/5 	 lr=1.5e-05 	 t=22s 	 loss=0.041 	 mAP=0.871 	 val_loss=0.071
# Epoch 5/5 	 lr=1.0e-06 	 t=22s 	 loss=0.037 	 mAP=0.871 	 val_loss=0.071
#
# - Evaluating:
#
#  - Scored 0.871 on validation data

# %%
backbone = 'resnet101'
model = train_ssgrl(backbone, trainval_dataset, test_dataset, coocurence, class_embeddings, 
                    model_name=backbone, use_si=False)
# Out:
# - Training with frozen backbone :
#     -> 34877461 trainable parameters
#
# Epoch 1/3 	 lr=1.0e-03 	 t=36s 	 loss=0.198 	 mAP=0.791 	 val_loss=0.112
# Epoch 2/3 	 lr=5.5e-04 	 t=36s 	 loss=0.115 	 mAP=0.829 	 val_loss=0.092
# Epoch 3/3 	 lr=1.0e-04 	 t=36s 	 loss=0.093 	 mAP=0.845 	 val_loss=0.080
#
# - Training :
#     -> 49842197 trainable parameters
#
# Epoch 1/5 	 lr=1.0e-04 	 t=39s 	 loss=0.088 	 mAP=0.872 	 val_loss=0.076
# Epoch 2/5 	 lr=8.6e-05 	 t=39s 	 loss=0.067 	 mAP=0.874 	 val_loss=0.072
# Epoch 3/5 	 lr=5.1e-05 	 t=39s 	 loss=0.053 	 mAP=0.877 	 val_loss=0.072
# Epoch 4/5 	 lr=1.5e-05 	 t=39s 	 loss=0.042 	 mAP=0.880 	 val_loss=0.069
# Epoch 5/5 	 lr=1.0e-06 	 t=39s 	 loss=0.038 	 mAP=0.880 	 val_loss=0.069
#
# - Evaluating:
#
#  - Scored 0.880 on validation data

# %%
backbone = 'resnet101'
model = train_ssgrl(backbone, trainval_dataset, test_dataset, coocurence, class_embeddings, 
                    model_name=backbone, use_si=True)
# Out:
# - Training with frozen backbone :
#     -> 43266069 trainable parameters
#
# Epoch 1/3 	 lr=1.0e-03 	 t=44s 	 loss=0.184 	 mAP=0.807 	 val_loss=0.109
# Epoch 2/3 	 lr=5.5e-04 	 t=44s 	 loss=0.113 	 mAP=0.835 	 val_loss=0.097
# Epoch 3/3 	 lr=1.0e-04 	 t=44s 	 loss=0.090 	 mAP=0.845 	 val_loss=0.082
#
# - Training :
#     -> 58230805 trainable parameters
#
# Epoch 1/5 	 lr=1.0e-04 	 t=46s 	 loss=0.088 	 mAP=0.872 	 val_loss=0.074
# Epoch 2/5 	 lr=8.6e-05 	 t=47s 	 loss=0.068 	 mAP=0.877 	 val_loss=0.071
# Epoch 3/5 	 lr=5.1e-05 	 t=46s 	 loss=0.053 	 mAP=0.878 	 val_loss=0.072
# Epoch 4/5 	 lr=1.5e-05 	 t=46s 	 loss=0.043 	 mAP=0.881 	 val_loss=0.069
# Epoch 5/5 	 lr=1.0e-06 	 t=46s 	 loss=0.039 	 mAP=0.880 	 val_loss=0.069
#
# - Evaluating:
#
#  - Scored 0.880 on validation data

# %%
backbone = 'resnext101'
model = train_ssgrl(backbone, trainval_dataset, test_dataset, coocurence, class_embeddings, 
                    model_name=backbone, use_si=False)
# Out:
# - Training with frozen backbone :
#     -> 34877461 trainable parameters
#
# Epoch 1/3 	 lr=1.0e-03 	 t=61s 	 loss=0.123 	 mAP=0.895 	 val_loss=0.073
# Epoch 2/3 	 lr=5.5e-04 	 t=60s 	 loss=0.075 	 mAP=0.912 	 val_loss=0.064
# Epoch 3/3 	 lr=1.0e-04 	 t=60s 	 loss=0.062 	 mAP=0.915 	 val_loss=0.057
#
# - Training :
#     -> 63623189 trainable parameters
#
# Epoch 1/5 	 lr=1.0e-04 	 t=66s 	 loss=0.065 	 mAP=0.925 	 val_loss=0.054
# Epoch 2/5 	 lr=8.6e-05 	 t=66s 	 loss=0.044 	 mAP=0.928 	 val_loss=0.053
# Epoch 3/5 	 lr=5.1e-05 	 t=66s 	 loss=0.031 	 mAP=0.930 	 val_loss=0.051
# Epoch 4/5 	 lr=1.5e-05 	 t=66s 	 loss=0.022 	 mAP=0.932 	 val_loss=0.050
# Epoch 5/5 	 lr=1.0e-06 	 t=66s 	 loss=0.018 	 mAP=0.933 	 val_loss=0.049
#
# - Evaluating:
#
#  - Scored 0.933 on validation data

# %%
backbone = 'resnext101'
model = train_ssgrl(backbone, trainval_dataset, test_dataset, coocurence, class_embeddings, 
                    model_name=backbone, use_si=True)
# Out:
# - Training with frozen backbone :
#     -> 34834453 trainable parameters
#
# Epoch 1/3 	 lr=1.0e-03 	 t=64s 	 loss=0.109 	 mAP=0.898 	 val_loss=0.075
# Epoch 2/3 	 lr=5.5e-04 	 t=66s 	 loss=0.072 	 mAP=0.910 	 val_loss=0.063
# Epoch 3/3 	 lr=1.0e-04 	 t=66s 	 loss=0.061 	 mAP=0.913 	 val_loss=0.058
#
# - Training :
#     -> 63580181 trainable parameters
#
# Epoch 1/5 	 lr=1.0e-04 	 t=72s 	 loss=0.067 	 mAP=0.918 	 val_loss=0.057
# Epoch 2/5 	 lr=8.6e-05 	 t=72s 	 loss=0.046 	 mAP=0.926 	 val_loss=0.052
# Epoch 3/5 	 lr=5.1e-05 	 t=72s 	 loss=0.032 	 mAP=0.927 	 val_loss=0.051
# Epoch 4/5 	 lr=1.5e-05 	 t=72s 	 loss=0.023 	 mAP=0.930 	 val_loss=0.050
# Epoch 5/5 	 lr=1.0e-06 	 t=72s 	 loss=0.019 	 mAP=0.929 	 val_loss=0.050
#
# - Evaluating:
#
#  - Scored 0.929 on validation data

# %%
plot_attention_ssgrl(model, test_dataset, 0)

# %% [markdown]
# - Change embed
